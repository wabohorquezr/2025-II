# %% [markdown]
# # Identificación de sistemas por medio de la curva de reacción (respuesta al escalón).
#
#
# En esta práctica vamos a obtener el modelo por curva de reacción y el modelo estático para un sistema térmico. También lo haremos para un motor DC considerando como salida la velocidad. Usaremos para ello las plantas diseñadas en la universidad denominadoss UNThermal y UNDCMotor.
#
# + El UNThermal es un minilaboratorio que permite realizar el control de temperatura de un par transistor-sensor mediante la administración precisa de potencia eléctrica controlada por una fuente de corriente analógica.
#
# + El UNDCMotor es un minilaboratorio que permite realizar el control de velocidad y ángulo de giro de un motor DC.

# %% [markdown]
# ## Configuración
# ---

# %% [markdown]
# ### Instalación de las librerias unthermal y unmotor
#
# Ejecutar esta celda solo para instalar por primera vez o actualizar la libreria. __Asegúrese de instalar  [Git](https://git-scm.com/download/win/ "Git").__
#
# <div class="alert alert-block alert-danger">
# ⚠️ Ejecutar esta celda solo para instalar por primera vez o actualizar la libreria.
# </div>

# %%
import subprocess
command = ["pip", "install", "-I", "git+https://github.com/nebisman/UNThermal.git@main#subdirectory=code/python_code"]
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in process.stdout:
    print(line.strip())

command = ["pip", "install", "-I","git+https://github.com/nebisman/UNDCMotor.git@main#subdirectory=code/python_code"]
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in process.stdout:
    print(line.strip())
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/nebisman/UNThermal.git@main#subdirectory=code/python_code
# Cloning https://github.com/nebisman/UNThermal.git (to revision main) to c:\users\alex\appdata\local\temp\pip-req-build-mqfy5g5c
# Running command git clone --filter=blob:none --quiet https://github.com/nebisman/UNThermal.git 'C:\Users\alex\AppData\Local\Temp\pip-req-build-mqfy5g5c'
# Resolved https://github.com/nebisman/UNThermal.git to commit 5aca138916c8c34a3c53da8963876e9749ddb7c0
# Installing build dependencies: started
# Installing build dependencies: finished with status 'done'
# Getting requirements to build wheel: started
# Getting requirements to build wheel: finished with status 'done'
# Preparing metadata (pyproject.toml): started
# Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting iottalk-paho-mqtt (from unthermal==0.1.13)
# Downloading iottalk_paho_mqtt-1.5.1-py3-none-any.whl.metadata (46 kB)
# Collecting control (from unthermal==0.1.13)
# Downloading control-0.10.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting numpy (from unthermal==0.1.13)
# Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib (from unthermal==0.1.13)
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from unthermal==0.1.13)
# Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting ipympl (from unthermal==0.1.13)
# Downloading ipympl-0.9.7-py3-none-any.whl.metadata (8.7 kB)
# Collecting mplcursors (from unthermal==0.1.13)
# Downloading mplcursors-0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->unthermal==0.1.13)
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->unthermal==0.1.13)
# Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->unthermal==0.1.13)
# Downloading fonttools-4.58.0-cp312-cp312-win_amd64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->unthermal==0.1.13)
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting packaging>=20.0 (from matplotlib->unthermal==0.1.13)
# Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib->unthermal==0.1.13)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->unthermal==0.1.13)
# Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib->unthermal==0.1.13)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting ipython<10 (from ipympl->unthermal==0.1.13)
# Using cached ipython-9.2.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl->unthermal==0.1.13)
# Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting traitlets<6 (from ipympl->unthermal==0.1.13)
# Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting colorama (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython<10->ipympl->unthermal==0.1.13)
# Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting comm>=0.1.3 (from ipywidgets<9,>=7.6.0->ipympl->unthermal==0.1.13)
# Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets<9,>=7.6.0->ipympl->unthermal==0.1.13)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets<9,>=7.6.0->ipympl->unthermal==0.1.13)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib->unthermal==0.1.13)
# Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython<10->ipympl->unthermal==0.1.13)
# Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl->unthermal==0.1.13)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython<10->ipympl->unthermal==0.1.13)
# Using cached executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython<10->ipympl->unthermal==0.1.13)
# Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython<10->ipympl->unthermal==0.1.13)
# Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading control-0.10.1-py3-none-any.whl (549 kB)
# ---------------------------------------- 0.0/549.6 kB ? eta -:--:--
# ---------------------------------------- 549.6/549.6 kB 4.6 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
# --- ------------------------------------ 0.8/8.1 MB 4.8 MB/s eta 0:00:02
# --------- ------------------------------ 1.8/8.1 MB 5.0 MB/s eta 0:00:02
# --------------- ------------------------ 3.1/8.1 MB 5.8 MB/s eta 0:00:01
# ----------------------- ---------------- 4.7/8.1 MB 6.1 MB/s eta 0:00:01
# ----------------------------- ---------- 6.0/8.1 MB 6.3 MB/s eta 0:00:01
# ------------------------------------- -- 7.6/8.1 MB 6.4 MB/s eta 0:00:01
# ---------------------------------------- 8.1/8.1 MB 6.3 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
# ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
# ---- ----------------------------------- 1.3/12.6 MB 7.4 MB/s eta 0:00:02
# --------- ------------------------------ 2.9/12.6 MB 7.3 MB/s eta 0:00:02
# ------------- -------------------------- 4.2/12.6 MB 7.2 MB/s eta 0:00:02
# ------------------ --------------------- 5.8/12.6 MB 7.3 MB/s eta 0:00:01
# ---------------------- ----------------- 7.1/12.6 MB 7.2 MB/s eta 0:00:01
# -------------------------- ------------- 8.4/12.6 MB 7.1 MB/s eta 0:00:01
# ------------------------------- -------- 10.0/12.6 MB 7.1 MB/s eta 0:00:01
# ------------------------------------ --- 11.5/12.6 MB 7.1 MB/s eta 0:00:01
# ---------------------------------------- 12.6/12.6 MB 7.0 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
# ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
# - -------------------------------------- 1.3/41.0 MB 6.7 MB/s eta 0:00:06
# -- ------------------------------------- 2.6/41.0 MB 6.6 MB/s eta 0:00:06
# --- ------------------------------------ 3.9/41.0 MB 6.7 MB/s eta 0:00:06
# ---- ----------------------------------- 5.0/41.0 MB 6.2 MB/s eta 0:00:06
# ------ --------------------------------- 6.3/41.0 MB 6.2 MB/s eta 0:00:06
# ------- -------------------------------- 7.9/41.0 MB 6.3 MB/s eta 0:00:06
# --------- ------------------------------ 9.4/41.0 MB 6.5 MB/s eta 0:00:05
# ---------- ----------------------------- 10.7/41.0 MB 6.6 MB/s eta 0:00:05
# ------------ --------------------------- 12.3/41.0 MB 6.6 MB/s eta 0:00:05
# ------------- -------------------------- 13.6/41.0 MB 6.6 MB/s eta 0:00:05
# -------------- ------------------------- 14.7/41.0 MB 6.5 MB/s eta 0:00:05
# --------------- ------------------------ 16.0/41.0 MB 6.5 MB/s eta 0:00:04
# ---------------- ----------------------- 17.3/41.0 MB 6.5 MB/s eta 0:00:04
# ------------------ --------------------- 18.9/41.0 MB 6.5 MB/s eta 0:00:04
# ------------------- -------------------- 20.4/41.0 MB 6.6 MB/s eta 0:00:04
# --------------------- ------------------ 22.0/41.0 MB 6.7 MB/s eta 0:00:03
# ---------------------- ----------------- 23.3/41.0 MB 6.7 MB/s eta 0:00:03
# ------------------------ --------------- 24.9/41.0 MB 6.7 MB/s eta 0:00:03
# ------------------------- -------------- 26.2/41.0 MB 6.7 MB/s eta 0:00:03
# --------------------------- ------------ 27.8/41.0 MB 6.7 MB/s eta 0:00:02
# ---------------------------- ----------- 29.1/41.0 MB 6.7 MB/s eta 0:00:02
# ----------------------------- ---------- 30.7/41.0 MB 6.8 MB/s eta 0:00:02
# ------------------------------- -------- 32.0/41.0 MB 6.7 MB/s eta 0:00:02
# -------------------------------- ------- 33.6/41.0 MB 6.8 MB/s eta 0:00:02
# ---------------------------------- ----- 34.9/41.0 MB 6.8 MB/s eta 0:00:01
# ----------------------------------- ---- 36.2/41.0 MB 6.8 MB/s eta 0:00:01
# ------------------------------------ --- 37.5/41.0 MB 6.7 MB/s eta 0:00:01
# ------------------------------------- -- 38.8/41.0 MB 6.7 MB/s eta 0:00:01
# ---------------------------------------  40.1/41.0 MB 6.7 MB/s eta 0:00:01
# ---------------------------------------  40.9/41.0 MB 6.7 MB/s eta 0:00:01
# ---------------------------------------- 41.0/41.0 MB 6.6 MB/s eta 0:00:00
# Downloading iottalk_paho_mqtt-1.5.1-py3-none-any.whl (61 kB)
# Downloading ipympl-0.9.7-py3-none-any.whl (515 kB)
# Downloading mplcursors-0.6-py3-none-any.whl (20 kB)
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.0-cp312-cp312-win_amd64.whl (2.2 MB)
# ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ----------------------- ---------------- 1.3/2.2 MB 7.4 MB/s eta 0:00:01
# ---------------------------------------- 2.2/2.2 MB 6.6 MB/s eta 0:00:00
# Using cached ipython-9.2.0-py3-none-any.whl (604 kB)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
# ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
# ------------------- -------------------- 1.3/2.7 MB 6.7 MB/s eta 0:00:01
# ------------------------------- -------- 2.1/2.7 MB 5.9 MB/s eta 0:00:01
# ----------------------------------- ---- 2.4/2.7 MB 4.3 MB/s eta 0:00:01
# ---------------------------------------- 2.7/2.7 MB 3.8 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
# Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ----------------------- ---------------- 1.3/2.2 MB 7.4 MB/s eta 0:00:01
# ---------------------------------------- 2.2/2.2 MB 6.5 MB/s eta 0:00:00
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: unthermal
# Building wheel for unthermal (pyproject.toml): started
# Building wheel for unthermal (pyproject.toml): finished with status 'done'
# Created wheel for unthermal: filename=unthermal-0.1.13-py3-none-any.whl size=32917 sha256=fbe75c288f9f2a2afd5bd58d12e0820019ac404d18013c367dadb1aa9ec23ae1
# Stored in directory: C:\Users\alex\AppData\Local\Temp\pip-ephem-wheel-cache-hkbb7d7r\wheels\fe\8b\76\f1fff953b394c84ac9694bb0a816e6c180e3a3bdeaf2e9181b
# Successfully built unthermal
# Installing collected packages: wcwidth, pure-eval, iottalk-paho-mqtt, widgetsnbextension, traitlets, six, pyparsing, pygments, prompt_toolkit, pillow, parso, packaging, numpy, kiwisolver, jupyterlab_widgets, fonttools, executing, decorator, cycler, colorama, asttokens, stack_data, scipy, python-dateutil, matplotlib-inline, jedi, ipython-pygments-lexers, contourpy, comm, matplotlib, ipython, mplcursors, ipywidgets, control, ipympl, unthermal
# Successfully installed asttokens-3.0.0 colorama-0.4.6 comm-0.2.2 contourpy-1.3.2 control-0.10.1 cycler-0.12.1 decorator-5.2.1 executing-2.2.0 fonttools-4.58.0 iottalk-paho-mqtt-1.5.1 ipympl-0.9.7 ipython-9.2.0 ipython-pygments-lexers-1.1.1 ipywidgets-8.1.7 jedi-0.19.2 jupyterlab_widgets-3.0.15 kiwisolver-1.4.8 matplotlib-3.10.3 matplotlib-inline-0.1.7 mplcursors-0.6 numpy-2.2.5 packaging-25.0 parso-0.8.4 pillow-11.2.1 prompt_toolkit-3.0.51 pure-eval-0.2.3 pygments-2.19.1 pyparsing-3.2.3 python-dateutil-2.9.0.post0 scipy-1.15.3 six-1.17.0 stack_data-0.6.3 traitlets-5.14.3 unthermal-0.1.13 wcwidth-0.2.13 widgetsnbextension-4.0.14
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\alex\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/nebisman/UNDCMotor.git@main#subdirectory=code/python_code
# Cloning https://github.com/nebisman/UNDCMotor.git (to revision main) to c:\users\alex\appdata\local\temp\pip-req-build-k60jmrfe
# Running command git clone --filter=blob:none --quiet https://github.com/nebisman/UNDCMotor.git 'C:\Users\alex\AppData\Local\Temp\pip-req-build-k60jmrfe'
# Resolved https://github.com/nebisman/UNDCMotor.git to commit be8b2b1781edb71b5fb7ff2f701b6edbee4e4459
# Installing build dependencies: started
# Installing build dependencies: finished with status 'done'
# Getting requirements to build wheel: started
# Getting requirements to build wheel: finished with status 'done'
# Preparing metadata (pyproject.toml): started
# Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting iottalk-paho-mqtt (from unmotor==0.1.13)
# Using cached iottalk_paho_mqtt-1.5.1-py3-none-any.whl.metadata (46 kB)
# Collecting control (from unmotor==0.1.13)
# Using cached control-0.10.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting numpy (from unmotor==0.1.13)
# Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib (from unmotor==0.1.13)
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from unmotor==0.1.13)
# Using cached scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting ipympl (from unmotor==0.1.13)
# Using cached ipympl-0.9.7-py3-none-any.whl.metadata (8.7 kB)
# Collecting mplcursors (from unmotor==0.1.13)
# Using cached mplcursors-0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->unmotor==0.1.13)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->unmotor==0.1.13)
# Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->unmotor==0.1.13)
# Using cached fonttools-4.58.0-cp312-cp312-win_amd64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->unmotor==0.1.13)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting packaging>=20.0 (from matplotlib->unmotor==0.1.13)
# Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib->unmotor==0.1.13)
# Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->unmotor==0.1.13)
# Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib->unmotor==0.1.13)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting ipython<10 (from ipympl->unmotor==0.1.13)
# Using cached ipython-9.2.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl->unmotor==0.1.13)
# Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting traitlets<6 (from ipympl->unmotor==0.1.13)
# Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting colorama (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython<10->ipympl->unmotor==0.1.13)
# Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting comm>=0.1.3 (from ipywidgets<9,>=7.6.0->ipympl->unmotor==0.1.13)
# Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets<9,>=7.6.0->ipympl->unmotor==0.1.13)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets<9,>=7.6.0->ipympl->unmotor==0.1.13)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib->unmotor==0.1.13)
# Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython<10->ipympl->unmotor==0.1.13)
# Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl->unmotor==0.1.13)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython<10->ipympl->unmotor==0.1.13)
# Using cached executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython<10->ipympl->unmotor==0.1.13)
# Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython<10->ipympl->unmotor==0.1.13)
# Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached control-0.10.1-py3-none-any.whl (549 kB)
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
# Using cached iottalk_paho_mqtt-1.5.1-py3-none-any.whl (61 kB)
# Using cached ipympl-0.9.7-py3-none-any.whl (515 kB)
# Using cached mplcursors-0.6-py3-none-any.whl (20 kB)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached ipython-9.2.0-py3-none-any.whl (604 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
# Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: unmotor
# Building wheel for unmotor (pyproject.toml): started
# Building wheel for unmotor (pyproject.toml): finished with status 'done'
# Created wheel for unmotor: filename=unmotor-0.1.13-py3-none-any.whl size=43287 sha256=34b410593f60398ac00a7cfb83e5b304aca288a6ac4526ed248c8981ae63092c
# Stored in directory: C:\Users\alex\AppData\Local\Temp\pip-ephem-wheel-cache-1qwru_ze\wheels\a3\7a\69\a73d4210d3ba794e248e02a316374edca632d3d33d84be1343
# Successfully built unmotor
# Installing collected packages: wcwidth, pure-eval, iottalk-paho-mqtt, widgetsnbextension, traitlets, six, pyparsing, pygments, prompt_toolkit, pillow, parso, packaging, numpy, kiwisolver, jupyterlab_widgets, fonttools, executing, decorator, cycler, colorama, asttokens, stack_data, scipy, python-dateutil, matplotlib-inline, jedi, ipython-pygments-lexers, contourpy, comm, matplotlib, ipython, mplcursors, ipywidgets, control, ipympl, unmotor
# Successfully installed asttokens-3.0.0 colorama-0.4.6 comm-0.2.2 contourpy-1.3.2 control-0.10.1 cycler-0.12.1 decorator-5.2.1 executing-2.2.0 fonttools-4.58.0 iottalk-paho-mqtt-1.5.1 ipympl-0.9.7 ipython-9.2.0 ipython-pygments-lexers-1.1.1 ipywidgets-8.1.7 jedi-0.19.2 jupyterlab_widgets-3.0.15 kiwisolver-1.4.8 matplotlib-3.10.3 matplotlib-inline-0.1.7 mplcursors-0.6 numpy-2.2.5 packaging-25.0 parso-0.8.4 pillow-11.2.1 prompt_toolkit-3.0.51 pure-eval-0.2.3 pygments-2.19.1 pyparsing-3.2.3 python-dateutil-2.9.0.post0 scipy-1.15.3 six-1.17.0 stack_data-0.6.3 traitlets-5.14.3 unmotor-0.1.13 wcwidth-0.2.13 widgetsnbextension-4.0.14
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\alex\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importación de comandos de la libreria unthermal y unmotor
#
# A continuación importamos los comandos básicos que usaremos de la libreria `unthermal` y la libreria `Matplotlib` para las figuras.

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import unthermal as temp
import numpy as np
import unmotor as mot

# %% [markdown]
# ---

# %% [markdown]
# ### Definición del sistema en el IoT
#
# Lo primero que necesitamos es definir el sistema y su conexión al IoT. Esto lo hacemos mediante el  comando
#
# `ThermalSystemIoT(plant_number="xxxx", broker_address = "xx.xxx.xxx.xxx")`.
#
# + El parámetro `plant_number` es el identificador de la planta con que está trabajando. Por ejemplo `plant_number="PC-T-XX"`
#
# + El parámetro `broker_address` es la dirección IP del broker al cual se conecta la planta. Poner siempre ` broker_address = "192.168.1.100"`

# %%
sistema_termico = temp.ThermalSystemIoT(plant_number = "PC-T-XX" , broker_address = "192.168.1.100")

# %% [markdown]
# ## Modelos estático y dinámico del sistema térmico
# ---
#
# A continuación vamos a obtener tanto el modelo estático, como el modelo dinámico por respuesta al escalón del sistema térmico

# %% [markdown]
# ### Modelo estático del sistema térmico
#
# Es natural comenzar investigando el comportamiento estacionario de un sistema bajo
# control. Esto se hace mediante una curva que muestra el valor en estado estacionario de la
# salida (en este caso, la temperatura del par transistor-sensor) para diferentes valores de la variable de entrada (en este caso la potencia aplicada). A esta curva se le denomina Modelo Estático del Sistema.
#
#
# El modelo estático se puede obtener experimentalmente de varias formas. *Una manera
# es que el sistema esté en lazo cerrado con un controlador preajustado e ir ajustando diferentes valores de la referencia. Cuando la salida (en este caso la temperatura) alcanza el valor estacionario de referencia, se registra la señal de control que fue necesaria. Esto da un punto del modelo estático. Este procedimiento se repite para cubrir el rango completo de entradas.*
#
#
#
# + La  función `get_static_model(system)` nos permite obtener el modelo estático del UNThermal definido por la instancia del UNThermal creada con la función  `ThermalSystemIoT(.)`
# + La funcion `plt.savefig(.)` permite guardar la figura en en cualquier formato para su video informe
# + `plt.show` hace que su figura se guarde al guardar y cerrar el notebook.
#
#
# *Note que la salida los valores de estado estacionario de la entrada y la salida quedan registrados en las variables `ue`, `ye`. También quedan guardados en el archivo `\experiment_files\DCmotor_static_gain_response.csv` presente en la carpeta en la que ejecuta este script.*

# %%
ue, ye = temp.get_static_model(sistema_termico) 
plt.savefig("static_model.pdf", format="pdf", bbox_inches="tight") # la figura se guarda en el archivo que ud desee
plt.show() # esta linea es para que la figura se mantenga al guardar el notebook

# %% [markdown]
# ### Preguntas orientadoras sobre el modelo estático
#
# Por favor discuta las preguntas con su compañero inmediatamente durante la práctica y respondalas en su videoinforme
#
# 1.  Considere que el rango de operación va desde  $40^oC$ hasta $100^oC$. ¿Existen temperaturas en este rango más dificiles de controlar, según el modelo estático?
# 2.  Suponga que un modelo aproximado del sistema térmico está dado por $G(s)=\frac{\alpha}{\tau\,s+1}$. ¿Cual de los parámetros ($\alpha$ o $\tau$) podriamos asumir como aproximadamente constante, según la curva del modelo estático?
# 3.  ¿Cual es la señal de control necesaria para controlar una temperatura cercana a $60^oC$ y cuanto nos queda de acción de control si tenemos que compensar una temperatura muy fria que actúa como perturbación?

# %% [markdown]
# ### Modelo dinámico por respuesta al escalón
#
# Cuando se realiza la linealización del modelo del UNThermal se obtiene un  modelo lineal de primer orden, tal y como puede revisar en este [documento](https://github.com/nebisman/UNDCMotor/blob/main/docs/modelo_matematico_unmotor.pdf).
#
# Así, nuestro sistema térmico, dentro de una región cercana al punto de operación, puede ser descrito por la siguiente función de transferencia:
#
# $$G(s)= \frac{\alpha}{\tau\, s + 1} \, e^{-L\,s}$$
#
# Es usual que la primera prueba de identificación de sistemas que parecen de primer orden sea por la respuesta al escalón.

# %% [markdown]
# ### Método de estimación de los parámetros del sistema por la curva de reacción
#
#  A continuación usamos el método de 2 puntos para la identificación del modelo de primer orden, según el prodedimiento descrito en este [documento](https://github.com/nebisman/UNThermal/blob/main/docs/metodo_2_puntos.pdf).
#
#
#  Para iniciar hacemos el experimento de respuesta al escalón, usando el comando `step_open`.

# %%
# inicialmente hacemos el experimento de respuesta al escalón para 50 grados
temp.step_open(sistema_termico, yop=50, amplitude=10);

# %% [markdown]
# #### Paso 1
#
# Encuentre $y_a$ gráficamente o como el promedio de $N$ puntos antes del cambio del escalón y $y_b$ como el promedio de los últimos $N$ puntos registrados en la respuesta al escalón.
#
# Establezca el valor de $u_a$ y $u_b$.

# %%
# Paso 1
# Aqui leemos los resultados del experimento
t, u, y = temp.read_step_open_file('experiment_files/Thermal_step_open_exp.csv')
ind_step = np.diff(u).argmax() # es para detectar el indice del elemento donde ocurre el escalon


# este es el valor inicial del escalón antes del cambio
ua = u[ind_step]

# el último punto es el valor final del escalón
ub = u[-1]

# calculamos el valor inicial de temperatura antes del cambio en el escalón
# como el promedio de los 10 puntos antes del cambio
ya = np.mean(y[ind_step-10:ind_step+1])

# para el valor final de la temperatura tomamos un promedio de las 10 últimas valores
yb = np.mean(y[-10:]) 

# calculamos el cambio neto en el escalon
delta_u = ub - ua

# calculamos el cambio en el valor de estado estacionario de la salida
delta_y = yb - ya

# %% [markdown]
# #### Paso 2
#
# Con los datos experimentales, encuentre y grafique la respuesta experimental normalizada $\overline{y}(t)$ del sistema por medio de siguiente ecuación:
#
#  $$\overline{y}(t) = \frac{y(t)-y_a}{\Delta\,y}$$

# %%
# paso 2
# calculamos la respuesta normalizada
y_norm = (y - ya) / delta_y

#graficamos la respuesta normalizada
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title(r'Curva de respuesta normalizada $\overline{y}(t)$')
ax.set_facecolor('#f4eed7')
ax.plot(t,y_norm)
ax.grid(True)
ax.set_xlabel("Tiempo (s)")
plt.show()

# %% [markdown]
# #### Paso 3
#
# Encuentre por medio de interpolación numérica de la curva experimental los valores de tiempo $t_1, t_2$ en los cuales la respuesta experimental normalizada $\overline{y}(t)$ alcanza dos valores en la zona inicial de máxima pendiente de la curva, en la cual $\overline{y}(t)\leq 0.5$.
#
# Por ejemplo, $\overline{y}_1=0.05$ y $\overline{y}_2=0.3$.

# %%
# Paso 3 
# Definimos los puntos y1n=0.1, y y2n=0.3 y encontramos los tiempos en que se producen por interpolación numérica
y1n = 0.05
y2n = 0.3
t1 = np.interp(y1n, y_norm, t) 
t2 = np.interp(y2n, y_norm, t) 

#graficamos estos puntos en la figura anterior para ilustrar
ax.scatter([t1, t2],[y1n,y2n],color='b')
ax.text( t1+10,y1n, f'$t_1=${t1:0.2f}  '+r'$\overline{y}_1$='+f'{y1n:0.2f}', fontsize=12, color='b')
ax.text( t2+10,y2n, f'$t_2=${t2:0.2f}  '+r'$\overline{y}_2$='+f'{y2n:0.2f}', fontsize=12, color='b')
plt.show()

# %% [markdown]
# #### Paso 4
# Calcule $L$, $\tau$ y $\alpha$ usando las  siguientes ecuaciones:
#
# $$\tau= \frac{t_2-t_1}{\ln(\frac{1-\overline{y}_1}{1-\overline{y}_2})}$$
#
# $$L = t_1 + \tau \ln (1-\overline{y}_1)$$
#
# $$\alpha =  \frac{\Delta\,y}{\Delta_u}$$

# %%
# Paso 4 calculamos los valores estimados de tao, L y alpha


tau = (t2-t1)/np.log((1-y1n)/(1-y2n))
L = np.max([0,t1 + tau * np.log(1-y1n)])
alpha = delta_y / delta_u

# %%
def compute_step_response(t, alpha, tau, L):
    # esta función calcula la respuesta al escalon con los parametros
    ym = []
    for ti in t:
        yi = alpha * delta_u * (1 - np.exp(-np.max([0, ti-L]) / tau)) + ya
        ym.append(yi)
    return ym


# calculamos la respuesta del modelo
ymodel = compute_step_response(t, alpha, tau, L)

# ahora graficamos la salida comparar los resultados
fig, (ay, au) = plt.subplots(2, 1, figsize=(10, 6),height_ratios=[4, 1])
ay.plot(t, y, t, ymodel)
ay.grid(True)
ay.set_title('Temperatura')
ay.set_facecolor('#f4eed7')
ay.legend(["Datos", r"Modelo $G(s)= \frac{\alpha_m}{\tau_m\,s + 1} e^{-L\,s} = \frac{%0.3f }{%0.3f\,s+1}e^{-%0.2f\,s}$" %(alpha, tau, L)])


# En este gráfico está la entrada escalón
au.plot(t, u, label='% de potencia de entrada', color="#00aa00")
au.set_xlabel("Tiempo")
au.set_facecolor('#d7f4ee')
au.grid(True)
au.legend(["Porcentaje de potencia"])
plt.show()

# %% [markdown]
# #### Función completa para la identificación del modelo de primer orden
#
# Todos los pasos anteriores están sintetizados en la función `get_fomodel_step(system, yop = desired_op)`. Esta función, además, utiliza una estimación más precisa de las constantes usando 4 puntos y mínimos cuadrados.
#
#
# + El parámetro `system` es la instancia creada con la función  `ThermalSystemIoT(.)`
#
# + El parámetro `yop = desired_op` permite obtener la respuesta al escalón con un cambio de potencia que inicia exactamente en el punto de operación `yop`.
#
# +  `alpha, tau` y `L` son los parámetros del sistema térmico.
#
# En el ejemplo siguiente obtenemos la respuesta al escalón y el modelo para un punto de operación.

# %%
#Ejemplo
alpha, tau, L = temp.get_fomodel_step(sistema_termico, yop = 50, amplitude=10, t1=600)

# %% [markdown]
# ### Trabajo experimental con el sistema térmico
#
# + Obtenga modelos para el sistema térmico en los puntos de operación de $60^o$ y $80^o$ usando la función `get_fomodel_step`.
#
# #### Preguntas orientadoras sobre los modelos dinámicos
#
# + Compare  los modelos obtenidos  a $60^o$ y a  $80^o$ ¿Son similares los parámetros obtenidos en cada uno de estos modelos?
#
# + Consideremos el modelo estático y los dos modelos dinámicos. Discuta que diferencias podrían existir al controlar el sistema térmico en un punto de operación cercano a $60^o$ y en un punto cercano a $80^o$.

# %% [markdown]
# ## Modelo estático y dinámico para el Motor DC
# ___
#
# A continuación vamos a realizar el trabajo de un modelo estático y dinámico para el Motor DC. Para ello. primero definimos la planta como objeto IoT. Esto lo hacemos a continuación:

# %%
my_motor = mot.MotorSystemIoT(plant_number = "PC-M-08", broker_address = "192.168.1.100")

# %% [markdown]
# ### Modelo estático del Motor DC
#
#
#
# El modelo estático se puede obtener experimentalmente de varias formas. *otra manera
# habitual es ajustar un valor constante de entrada y medir la salida en estado estacionario.
# Esto da un punto del modelo estático. Este procedimiento se repite para cubrir el
# rango completo de entradas.*
#
# + La  función `get_static_model(m)` nos permite obtener el modelo estático del UNDCmotor definido por la instancia del UNDCMotor creada con la función  `MotorSystemIoT(.)`
#
# + La función `plt.savefig(.)` permite guardar la figura en en cualquier formato.

# %%
ue, ye = mot.get_static_model(my_motor) 
plt.savefig("static_model.pdf", format="pdf", bbox_inches="tight") # la figura se guarda en el archivo que ud desee
plt.show() # esta linea es para que la figura se mantenga al guardar el notebook
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Static model esperiment has been completed
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Preguntas orientadoras sobre el modelo estático
#
# Discuta estas preguntas con su compañero e incluya una respuesta breve en su video informe.
#
# 1.  ¿Cuál es la zona muerta del motor?
#
# Las zonas muertas del motor conrresponden a:
#
#  -  a las velocidades  mayores a -0.64(grados/segundos)y menores a 57(grados/segundos); adicionalmente vemos que claramente no contiene ningun tipo de movimiento entre tencieones menores ya sea a 0.3v y -0.3v.
#
# 2.  ¿Para cuales rangos de velocidad podría ser difícil controlar el motor?
#
# -  los rangos de velocidad son mas dificiles entre los puntos mas cercanos a la tension 0, adicionalmente vemos que el cambio de velociada es muy fuerte entre las velociades |400(grados/segundos)|y el |0(grados/segundos)|, donde en este cambio solo necesito 1v y en los siguientes apenas cambia unos cientos de grados por cada volteos, mientras en entre mayor voltaje unas decenas de (grados/segundos)
#
# 3.  ¿Hasta que velocidad máxima se puede controlar el motor?
#
# - El motor se puede contrrola a una velociada maxima de 700((grados/segundos))
#
# 4.  Suponga que un modelo aproximado del motor está dado por $G(s)=\frac{\alpha}{\tau\,s+1}$. ¿Cual de los parámetros ($\alpha$ o $\tau$) varía ampliamente, según se ve reflejado en la  no linealidad  de la curva del modelo estático?
#
# - En la curva del modelo estático no vemos representado muchas cosas, entre ellas el cambio del Tau porque no vemos un pasa paso o una rampa, si no que vemos la relacion de la amplitud donde la salida es la velocidad con respondiente a la entrada que es la tension, por ende podemos decir que $\alpha$ es la que varia ampliamente.

# %% [markdown]
# ### Modelo dinámico por respuesta al escalón
# ---
#
# Un motor DC puede ser descrito con muy buena aproximación por un  [modelo lineal de primer orden](https://github.com/nebisman/UNDCMotor/blob/main/docs/modelo_matematico_unmotor.pdf), si consideramos que la entrada es tensión y la salida es la velocidad angular.
#
# Así, el UNDCMotor puede ser descrito por la siguiente función de transferencia:
#
# $$G(s)= \frac{\alpha}{\tau\, s + 1} e^{-sL}$$
#
# *Note que el retardo fundamentalmente aparece por el tiempo de muestreo del sistema digital que procesa la información.*
#
#
#
# La función `get_fomodel_step(system, yop = desired_op)`  *(get first order model by using step response)* permite obtener la respuesta al escalón y el modelo matemático del UNDCMotor
#
# + El parámetro `system` es la instancia del UNDCMotor creada con la función  `MotorSystemIoT(.)`
#
# + El parámetro `yop = desired_op` permite obtener la respuesta al escalón con un cambio de tensión que centra, aproximadamente, los valores final e inicial del escalón en el punto de operación `yop`.
#
# +  `alpha, tau` y `L` retornan los parámetros del motor.
#
# En el ejemplo siguiente obtenemos la respuesta al escalón y el modelo para un punto de operación.

# %%
#Ejemplo
alpha, tau, L = mot.get_fomodel_step(my_motor, yop = 200)
plt.savefig("first_order_model_yop_200.pdf", format="png", bbox_inches="tight") # para salvar la figura
plt.show() # para congelarla en el notebook
# Out:
# Connected successfully to MQTT Broker!
# Subscribed:  74   (2,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 0.4653005 0.59591091
# 149.78572937459998 240.04287750400002
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Trabajo experimental con el motor
#
# Encuentre los modelos dinámicos por respuesta al escalón para los siguientes puntos de operación:
#
# + $y_{OP}=150^o/s$
# + $y_{OP}=300^o/s$
# + $y_{OP}=600^o/s$
#
# #### Preguntas sobre el modelo por respuesta al escalón
#
# + Describa como cambia la constante de tiempo $\tau$ al incrementar la velocidad.
# + Discuta que pasaría si se requiere un controlador para garantizar velocidad de $10^o/s$ en este sistema.
# + Describa como cambia la constante de ganancia $\alpha$ al incrementar la velocidad.
# + Suponga que vamos a controlar el motor en velocidades que van desde $400^o/s$ a $600^o/s$. Realice multiples experimentos para obtener el modelo por curva de reacción y exprese los parámetros $\alpha$ y $\tau$ en términos de su intertidumbre absoluta.
# + ¿Cual sistema tiene mayor incertidumbre, el térmico o el motor. Discuta su respuesta

# %%
alpha, tau, L = mot.get_fomodel_step(my_motor, yop = 50)
plt.savefig("first_order_model_yop_10.png", format="png", bbox_inches="tight") # para salvar la figura
plt.show() # para congelarla en el notebook

# %% [markdown]
# ##### Respuestas de las preguntas sobre el modelo por respuesra escalon
#
# + La constante de tiempo $\tau$ al incrementar la velocidad, al ver que la velocidades del los puntos de operacion aumentan el $\tau$ disminuye, demanera poco evidente entre 150 y 300 pero significativamente enre 300 y 600
#
# +

# %%
#Ejemplo
alpha, tau, L = mot.get_fomodel_step(my_motor, yop = 150)

plt.savefig("first_order_model_yop_150.png", format="png", bbox_inches="tight") # para salvar la figura
plt.show() # para congelarla en el notebook
# Out:
# Connected successfully to MQTT Broker!
# Subscribed:  1   (2,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 0.36324835 0.4375011
# 119.95715041840002 204.04286529399997
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Ejemplo
alpha, tau, L = mot.get_fomodel_step(my_motor, yop = 300)
plt.savefig("first_order_model_yop_300.pdf", format="png", bbox_inches="tight") # para salvar la figura
plt.show() # para congelarla en el notebook
# Out:
# Connected successfully to MQTT Broker!
# Subscribed:  70   (2,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 0.59591091 0.78826904
# 218.8285998544 332.4857397419999
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Ejemplo
alpha, tau, L = mot.get_fomodel_step(my_motor, yop = 600)
plt.savefig("first_order_model_yop_600.png", format="png", bbox_inches="tight") # para salvar la figura
plt.show() # para congelarla en el notebook
# Out:
# Connected successfully to MQTT Broker!
# Subscribed:  72   (2,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 1.59681749 2.88520956
# 539.8714343266 646.714331052
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
